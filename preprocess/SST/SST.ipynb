# %%
# !pip install spacy==2.1.3
# !python -m spacy download en
# Out:
# Collecting spacy==2.1.3
#   Downloading spacy-2.1.3.tar.gz (27.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.7/27.7 MB 45.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [655 lines of output]
#       Collecting setuptools
#         Downloading setuptools-62.3.3-py3-none-any.whl (1.2 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.6 MB/s eta 0:00:00
#       Collecting wheel>0.32.0.<0.33.0
#         Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#       Collecting Cython
#         Downloading Cython-0.29.30-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (2.0 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.5 MB/s eta 0:00:00
#       Collecting cymem<2.1.0,>=2.0.2
#         Downloading cymem-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
#       Collecting preshed<2.1.0,>=2.0.1
#         Downloading preshed-2.0.1.tar.gz (113 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 42.4 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Downloading murmurhash-1.0.7-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
#       Collecting thinc==7.0.0.dev6
#         Downloading thinc-7.0.0.dev6.tar.gz (1.9 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 72.0 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting blis<0.3.0,>=0.2.1
#         Downloading blis-0.2.4.tar.gz (1.5 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.3 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting thinc_gpu_ops<0.1.0,>=0.0.1
#         Downloading thinc_gpu_ops-0.0.4.tar.gz (483 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.5/483.5 kB 54.1 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting numpy>=1.7.0
#         Downloading numpy-1.22.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 66.3 MB/s eta 0:00:00
#       Collecting wrapt<1.11.0,>=1.10.0
#         Downloading wrapt-1.10.11.tar.gz (27 kB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting plac<1.0.0,>=0.9.6
#         Using cached plac-0.9.6-py2.py3-none-any.whl (20 kB)
#       Collecting tqdm<5.0.0,>=4.10.0
#         Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#       Collecting six<2.0.0,>=1.10.0
#         Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
#       Collecting wasabi<1.1.0,>=0.0.9
#         Using cached wasabi-0.9.1-py3-none-any.whl (26 kB)
#       Collecting srsly<1.1.0,>=0.0.5
#         Downloading srsly-1.0.5-cp39-cp39-manylinux2014_x86_64.whl (184 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 kB 46.7 MB/s eta 0:00:00
#       Building wheels for collected packages: thinc, preshed, blis, thinc_gpu_ops, wrapt
#         Building wheel for thinc (setup.py): started
#         Building wheel for thinc (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [174 lines of output]
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.linux-x86_64-cpython-39
#             creating build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/api.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/describe.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/t2t.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/compat.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/loss.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/t2v.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/i2v.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/rates.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/v2v.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/about.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/check.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/misc.py -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/exceptions.py -> build/lib.linux-x86_64-cpython-39/thinc
#             creating build/lib.linux-x86_64-cpython-39/thinc/tests
#             copying thinc/tests/util.py -> build/lib.linux-x86_64-cpython-39/thinc/tests
#             copying thinc/tests/test_util.py -> build/lib.linux-x86_64-cpython-39/thinc/tests
#             copying thinc/tests/strategies.py -> build/lib.linux-x86_64-cpython-39/thinc/tests
#             copying thinc/tests/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/tests
#             copying thinc/tests/conftest.py -> build/lib.linux-x86_64-cpython-39/thinc/tests
#             copying thinc/tests/test_api_funcs.py -> build/lib.linux-x86_64-cpython-39/thinc/tests
#             creating build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_check_exceptions.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_pooling.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_hash_embed.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_loss.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_feature_extracter.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_ops.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_pytorch_wrapper.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_beam_search.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_about.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_affine.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_imports.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_mem.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_rates.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_difference.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_model.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             copying thinc/tests/unit/test_rnn.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/unit
#             creating build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_shape_check.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_batch_norm.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_pickle.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_basic_tagger.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_feed_forward.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_roundtrip_bytes.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_affine_learns.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             copying thinc/tests/integration/test_mnist.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/integration
#             creating build/lib.linux-x86_64-cpython-39/thinc/tests/linear
#             copying thinc/tests/linear/test_sparse_array.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/linear
#             copying thinc/tests/linear/test_avgtron.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/linear
#             copying thinc/tests/linear/test_linear.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/linear
#             copying thinc/tests/linear/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/tests/linear
#             creating build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             creating build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/pooling.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/vec2vec.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/vecs2vec.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/mem.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/_lsuv.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/train.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/vecs2vecs.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/util.py -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             creating build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/load_nlp.py -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/datasets.py -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/wrappers.py -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/hpbff.py -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             creating build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/attention.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/difference.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/softmax.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/feed_forward.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/embed.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/layernorm.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/relu.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/batchnorm.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/elu.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/maxout.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/selu.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/hash_embed.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/static_vectors.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/affine.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/resnet.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/convolution.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/rnn.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/feature_extracter.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/model.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/function_layer.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             copying thinc/neural/_classes/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/neural/_classes
#             creating build/lib.linux-x86_64-cpython-39/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_datasets.py -> build/lib.linux-x86_64-cpython-39/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_data_utils.py -> build/lib.linux-x86_64-cpython-39/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_generic_utils.py -> build/lib.linux-x86_64-cpython-39/thinc/extra/_vendorized
#             copying thinc/typedefs.pyx -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/structs.pyx -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/linalg.pyx -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/structs.pxd -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/__init__.pxd -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/typedefs.pxd -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/linalg.pxd -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/cpu.pxd -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/compile_time_constants.pxi -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/structs.cpp -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/typedefs.cpp -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/linalg.cpp -> build/lib.linux-x86_64-cpython-39/thinc
#             copying thinc/linear/avgtron.pyx -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/linear.pyx -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/serialize.pyx -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/features.pyx -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/sparse.pyx -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/features.pxd -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/serialize.pxd -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/sparse.pxd -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/__init__.pxd -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/avgtron.pxd -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/avgtron.cpp -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/features.cpp -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/serialize.cpp -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/linear.cpp -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/linear/sparse.cpp -> build/lib.linux-x86_64-cpython-39/thinc/linear
#             copying thinc/neural/optimizers.pyx -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/ops.pyx -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/_aligned_alloc.pyx -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/cpu.pxd -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/__init__.pxd -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/ops.pxd -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/optimizers.cpp -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/_aligned_alloc.cpp -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/neural/ops.cpp -> build/lib.linux-x86_64-cpython-39/thinc/neural
#             copying thinc/extra/eg.pyx -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/cache.pyx -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/search.pyx -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/mb.pyx -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/__init__.pxd -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/mb.pxd -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/eg.pxd -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/cache.pxd -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/search.pxd -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/eg.cpp -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/cache.cpp -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/search.cpp -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             copying thinc/extra/mb.cpp -> build/lib.linux-x86_64-cpython-39/thinc/extra
#             running build_ext
#             building 'thinc.linalg' extension
#             creating build/temp.linux-x86_64-cpython-39
#             creating build/temp.linux-x86_64-cpython-39/thinc
#             gcc -pthread -B /home/yila22/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/yila22/anaconda3/include -fPIC -O2 -isystem /home/yila22/anaconda3/include -fPIC -I/home/yila22/anaconda3/include/python3.9 -I/tmp/pip-install-c3vzorix/thinc_0f5c43c4cd1941009313c718b4fffc73/include -I/home/yila22/anaconda3/include/python3.9 -c thinc/linalg.cpp -o build/temp.linux-x86_64-cpython-39/thinc/linalg.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             thinc/linalg.cpp: In function ‘int __Pyx_modinit_type_init_code()’:
#             thinc/linalg.cpp:3872:36: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              3872 |   __pyx_type_5thinc_6linalg_Matrix.tp_print = 0;
#                   |                                    ^~~~~~~~
#             thinc/linalg.cpp:3897:33: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              3897 |   __pyx_type_5thinc_6linalg_Vec.tp_print = 0;
#                   |                                 ^~~~~~~~
#             thinc/linalg.cpp:3916:36: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              3916 |   __pyx_type_5thinc_6linalg_VecVec.tp_print = 0;
#                   |                                    ^~~~~~~~
#             thinc/linalg.cpp:3927:33: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              3927 |   __pyx_type_5thinc_6linalg_Mat.tp_print = 0;
#                   |                                 ^~~~~~~~
#             error: command '/usr/bin/gcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for thinc
#         Running setup.py clean for thinc
#         Building wheel for preshed (setup.py): started
#         Building wheel for preshed (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [328 lines of output]
#             /home/yila22/anaconda3/lib/python3.9/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#               warnings.warn(
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.linux-x86_64-cpython-39
#             creating build/lib.linux-x86_64-cpython-39/preshed
#             copying preshed/__init__.py -> build/lib.linux-x86_64-cpython-39/preshed
#             copying preshed/about.py -> build/lib.linux-x86_64-cpython-39/preshed
#             creating build/lib.linux-x86_64-cpython-39/preshed/tests
#             copying preshed/tests/test_pop.py -> build/lib.linux-x86_64-cpython-39/preshed/tests
#             copying preshed/tests/test_hashing.py -> build/lib.linux-x86_64-cpython-39/preshed/tests
#             copying preshed/tests/test_counter.py -> build/lib.linux-x86_64-cpython-39/preshed/tests
#             copying preshed/tests/__init__.py -> build/lib.linux-x86_64-cpython-39/preshed/tests
#             copying preshed/counter.pyx -> build/lib.linux-x86_64-cpython-39/preshed
#             copying preshed/maps.pyx -> build/lib.linux-x86_64-cpython-39/preshed
#             copying preshed/__init__.pxd -> build/lib.linux-x86_64-cpython-39/preshed
#             copying preshed/maps.pxd -> build/lib.linux-x86_64-cpython-39/preshed
#             copying preshed/counter.pxd -> build/lib.linux-x86_64-cpython-39/preshed
#             running build_ext
#             building 'preshed.maps' extension
#             creating build/temp.linux-x86_64-cpython-39
#             creating build/temp.linux-x86_64-cpython-39/preshed
#             gcc -pthread -B /home/yila22/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/yila22/anaconda3/include -fPIC -O2 -isystem /home/yila22/anaconda3/include -fPIC -I/home/yila22/anaconda3/include/python3.9 -I/home/yila22/anaconda3/include/python3.9 -c preshed/maps.cpp -o build/temp.linux-x86_64-cpython-39/preshed/maps.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             preshed/maps.cpp: In function ‘int __pyx_pf_7preshed_4maps_8PreshMap___init__(__pyx_obj_7preshed_4maps_PreshMap*, size_t)’:
#             preshed/maps.cpp:1727:35: warning: comparison of integer expressions of different signedness: ‘long int’ and ‘size_t’ {aka ‘long unsigned int’} [-Wsign-compare]
#              1727 |       __pyx_t_1 = ((__pyx_v_power < __pyx_v_initial_size) != 0);
#                   |                     ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp: In function ‘int __pyx_f_7preshed_4maps_map_iter(const __pyx_t_7preshed_4maps_MapStruct*, int*, __pyx_t_7preshed_4maps_key_t*, void**)’:
#             preshed/maps.cpp:4382:34: warning: comparison of integer expressions of different signedness: ‘int’ and ‘const __pyx_t_7preshed_4maps_key_t’ {aka ‘const long unsigned int’} [-Wsign-compare]
#              4382 |     __pyx_t_1 = (((__pyx_v_i[0]) < __pyx_v_map_->length) != 0);
#                   |                   ~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:4469:32: warning: comparison of integer expressions of different signedness: ‘int’ and ‘const __pyx_t_7preshed_4maps_key_t’ {aka ‘const long unsigned int’} [-Wsign-compare]
#              4469 |   __pyx_t_1 = (((__pyx_v_i[0]) == __pyx_v_map_->length) != 0);
#                   |                 ~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:4546:32: warning: comparison of integer expressions of different signedness: ‘int’ and ‘long unsigned int’ [-Wsign-compare]
#              4546 |   __pyx_t_1 = (((__pyx_v_i[0]) == (__pyx_v_map_->length + 1)) != 0);
#                   |                 ~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp: In function ‘int __Pyx_modinit_type_init_code()’:
#             preshed/maps.cpp:5728:38: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              5728 |   __pyx_type_7preshed_4maps_PreshMap.tp_print = 0;
#                   |                                      ^~~~~~~~
#             preshed/maps.cpp:5740:43: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              5740 |   __pyx_type_7preshed_4maps_PreshMapArray.tp_print = 0;
#                   |                                           ^~~~~~~~
#             preshed/maps.cpp:5749:55: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              5749 |   __pyx_type_7preshed_4maps___pyx_scope_struct__items.tp_print = 0;
#                   |                                                       ^~~~~~~~
#             preshed/maps.cpp:5755:55: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              5755 |   __pyx_type_7preshed_4maps___pyx_scope_struct_1_keys.tp_print = 0;
#                   |                                                       ^~~~~~~~
#             preshed/maps.cpp:5761:57: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              5761 |   __pyx_type_7preshed_4maps___pyx_scope_struct_2_values.tp_print = 0;
#                   |                                                         ^~~~~~~~
#             preshed/maps.cpp:5767:59: error: ‘PyTypeObject’ {aka ‘struct _typeobject’} has no member named ‘tp_print’
#              5767 |   __pyx_type_7preshed_4maps___pyx_scope_struct_3___iter__.tp_print = 0;
#                   |                                                           ^~~~~~~~
#             In file included from /home/yila22/anaconda3/include/python3.9/unicodeobject.h:1026,
#                              from /home/yila22/anaconda3/include/python3.9/Python.h:93,
#                              from preshed/maps.cpp:4:
#             preshed/maps.cpp: In function ‘int __Pyx_ParseOptionalKeywords(PyObject*, PyObject***, PyObject*, PyObject**, Py_ssize_t, const char*)’:
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6129:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6129:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6129:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6129:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6129:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6129 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6145:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6145:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6145:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             preshed/maps.cpp:6145:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             preshed/maps.cpp:6145:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#              6145 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /home/yila22/anaconda3/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             error: command '/usr/bin/gcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for preshed
#         Running setup.py clean for preshed
#         Building wheel for blis (setup.py): started
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): finished with status 'done'
#         Created wheel for blis: filename=blis-0.2.4-cp39-cp39-linux_x86_64.whl size=4128182 sha256=5fab7066dcadf2278abde6ca09acdbd5264f56db72bc19988f9fe380197f53be
#         Stored in directory: /home/yila22/.cache/pip/wheels/30/46/4d/5fdd1c2ca49afd37537c0666ad914fd1d40c467860ffa31d40
#         Building wheel for thinc_gpu_ops (setup.py): started
#         Building wheel for thinc_gpu_ops (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [20 lines of output]
#             /home/yila22/anaconda3/lib/python3.9/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#               warnings.warn(
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.linux-x86_64-cpython-39
#             creating build/lib.linux-x86_64-cpython-39/thinc_gpu_ops
#             copying thinc_gpu_ops/__init__.py -> build/lib.linux-x86_64-cpython-39/thinc_gpu_ops
#             copying thinc_gpu_ops/about.py -> build/lib.linux-x86_64-cpython-39/thinc_gpu_ops
#             copying thinc_gpu_ops/gpu_ops.pyx -> build/lib.linux-x86_64-cpython-39/thinc_gpu_ops
#             copying thinc_gpu_ops/gpu_ops.cpp -> build/lib.linux-x86_64-cpython-39/thinc_gpu_ops
#             running build_ext
#             building 'thinc_gpu_ops.gpu_ops' extension
#             creating build/temp.linux-x86_64-cpython-39
#             creating build/temp.linux-x86_64-cpython-39/include
#             creating build/temp.linux-x86_64-cpython-39/thinc_gpu_ops
#             /usr/local/cuda/bin/nvcc -I/home/yila22/anaconda3/include/python3.9 -I/tmp/pip-install-c3vzorix/thinc-gpu-ops_163a465611bd435186659dd879101cd9/include -I/usr/local/cuda/include -I/home/yila22/anaconda3/include/python3.9 -c include/_cuda_shim.cu -o build/temp.linux-x86_64-cpython-39/include/_cuda_shim.o -arch=sm_30 --ptxas-options=-v -c --compiler-options '-fPIC'
#             nvcc fatal   : Value 'sm_30' is not defined for option 'gpu-architecture'
#             error: command '/usr/local/cuda/bin/nvcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for thinc_gpu_ops
#         Running setup.py clean for thinc_gpu_ops
#         Building wheel for wrapt (setup.py): started
#         Building wheel for wrapt (setup.py): finished with status 'done'
#         Created wheel for wrapt: filename=wrapt-1.10.11-cp39-cp39-linux_x86_64.whl size=36745 sha256=d0aaf37850de21204fc965b8497fcdab89b4cd9eba4de405b0993417e8f11489
#         Stored in directory: /home/yila22/.cache/pip/wheels/06/72/65/c31a7174bc2bd89de6bfadcd92ab6fb425f93848b029cdef43
#       Successfully built blis wrapt
#       Failed to build thinc preshed thinc_gpu_ops
#       Installing collected packages: wrapt, wasabi, srsly, plac, murmurhash, cymem, wheel, tqdm, six, setuptools, preshed, numpy, Cython, thinc_gpu_ops, blis, thinc
#         Running setup.py install for preshed: started
#         Running setup.py install for preshed: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Running setup.py install for preshed did not run successfully.
#         │ exit code: 1
#         ╰─> [14 lines of output]
#             /home/yila22/anaconda3/lib/python3.9/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#               warnings.warn(
#             running install
#             /home/yila22/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#               warnings.warn(
#             running build
#             running build_py
#             running build_ext
#             building 'preshed.maps' extension
#             gcc -pthread -B /home/yila22/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/yila22/anaconda3/include -fPIC -O2 -isystem /home/yila22/anaconda3/include -fPIC -I/home/yila22/anaconda3/include/python3.9 -I/home/yila22/anaconda3/include/python3.9 -c preshed/maps.cpp -o build/temp.linux-x86_64-cpython-39/preshed/maps.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             gcc: error: preshed/maps.cpp: No such file or directory
#             gcc: fatal error: no input files
#             compilation terminated.
#             error: command '/usr/bin/gcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> preshed
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# /home/yila22/anaconda3/bin/python: No module named spacy

# %%
import nltk
a = nltk.corpus.BracketParseCorpusReader(".", "(train|dev|test)\.txt")

text = {}
labels = {}
keys = ['train', 'dev', 'test']
for k in keys :
    text[k] = [x.leaves() for x in a.parsed_sents(k+'.txt') if x.label() != '2']
    labels[k] = [int(x.label()) for x in a.parsed_sents(k+'.txt') if x.label() != '2']
    print(len(text[k]))
    
import spacy
nlp = spacy.load('en', disable=['parser', 'tagger', 'ner'])
import re

def tokenize(text) :
    text = " ".join(text)
    text = text.replace("-LRB-", '')
    text = text.replace("-RRB-", " ")
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    tokens = " ".join([t.text.lower() for t in nlp(text)])
    return tokens

for k in keys :
    text[k] = [tokenize(t) for t in text[k]]
    labels[k] = [1 if x >= 3 else 0 for x in labels[k]]
# Out:
# 6920
# 872
# 1821
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /mnt/yixin/tmp/ipykernel_29658/956473264.py in <module>
#      10     print(len(text[k]))
#      11
# ---> 12 import spacy
#      13 nlp = spacy.load('en', disable=['parser', 'tagger', 'ner'])
#      14 import re
#
# ModuleNotFoundError: No module named 'spacy'

# %%
import pandas as pd
df_texts = []
df_labels = []
df_exp_split = []

for k in keys :
    df_texts += text[k]
    df_labels += labels[k]
    df_exp_split += [k]*len(text[k])
    
df = pd.DataFrame({'text' : df_texts, 'label' : df_labels, 'exp_split' : df_exp_split})

# %%
df.to_csv('sst_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/yixin/tmp/ipykernel_29658/4223309172.py in <module>
# ----> 1 df.to_csv('sst_dataset.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
# %run "../preprocess_data_BC.py" --data_file sst_dataset.csv --output_file ./vec_sst.p --word_vectors_type fasttext.simple.300d --min_df 1
# Out:
# Vocabulary size :  13826
# Found 11171 words in model out of 13826
